# %% [markdown]
# <a href="https://colab.research.google.com/github/Sibin-S-S/Sibin_DSA_Pathshaala/blob/main/index_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>Netflix Content Dashboard</title>
    <style>
        :root {
            --bg: #0f172a;
            --card-bg: #111827;
            --accent: #e50914;
            --accent-soft: #f97373;
            --text-main: #f9fafb;
            --text-muted: #9ca3af;
            --border-color: #1f2937;
            --table-header-bg: #1f2937;
        }

        * { box-sizing: border-box; }

        body {
            font-family: system-ui, -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif;
            margin: 0;
            padding: 0;
            background-color: var(--bg);
            color: var(--text-main);
        }

        .page {
            max-width: 1200px;
            margin: 0 auto;
            padding: 24px 16px 40px;
        }

        header {
            display: flex;
            justify-content: space-between;
            align-items: baseline;
            margin-bottom: 24px;
            border-bottom: 1px solid var(--border-color);
            padding-bottom: 12px;
        }

        header h1 {
            font-size: 1.8rem;
            margin: 0;
        }

        header .subtitle {
            margin: 4px 0 0;
            color: var(--text-muted);
            font-size: 0.9rem;
        }

        .filter-bar {
            display: flex;
            align-items: center;
            gap: 8px;
            margin-bottom: 20px;
        }

        .filter-bar label {
            font-weight: 600;
            font-size: 0.9rem;
        }

        .filter-bar select {
            padding: 4px 8px;
            border-radius: 4px;
            border: 1px solid var(--border-color);
            background-color: var(--card-bg);
            color: var(--text-main);
        }

        .filter-bar button {
            padding: 5px 12px;
            border-radius: 4px;
            border: none;
            background-color: var(--accent);
            color: white;
            font-weight: 600;
            cursor: pointer;
        }

        .filter-bar button:hover {
            background-color: var(--accent-soft);
        }

        .chips {
            font-size: 0.85rem;
            color: var(--text-muted);
            margin-bottom: 8px;
        }

        .chip {
            display: inline-block;
            padding: 2px 8px;
            border-radius: 999px;
            background-color: var(--table-header-bg);
            margin-right: 6px;
        }

        .grid {
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(360px, 1fr));
            gap: 16px;
        }

        .card {
            background-color: var(--card-bg);
            border-radius: 8px;
            padding: 16px 16px 10px;
            border: 1px solid var(--border-color);
        }

        .card h2 {
            margin: 0 0 4px;
            font-size: 1.1rem;
        }

        .card .card-subtitle {
            margin: 0 0 12px;
            font-size: 0.85rem;
            color: var(--text-muted);
        }

        table {
            border-collapse: collapse;
            width: 100%;
            font-size: 0.85rem;
        }

        th, td {
            border-bottom: 1px solid var(--border-color);
            padding: 6px 8px;
            text-align: left;
        }

        th {
            background-color: var(--table-header-bg);
            font-weight: 600;
        }

        tr:nth-child(even) td {
            background-color: rgba(15, 23, 42, 0.6);
        }

        tr:hover td {
            background-color: rgba(55, 65, 81, 0.6);
        }

        .numeric {
            text-align: right;
            font-variant-numeric: tabular-nums;
        }

        footer {
            margin-top: 24px;
            font-size: 0.8rem;
            color: var(--text-muted);
            text-align: right;
        }
    </style>
</head>
<body>
<div class="page">
    <header>
        <div>
            <h1>Netflix Content Dashboard</h1>
            <p class="subtitle">
                Explore top actors and countries from the cleaned Netflix dataset.
            </p>
        </div>
    </header>

    <!-- Filter form -->
    <form method="POST" action="/" class="filter-bar">
        <label for="content_type">Filter by content type:</label>
        <select name="content_type" id="content_type">
            <option value="All" {% if selected_type == "All" %}selected{% endif %}>All</option>
            <option value="Movie" {% if selected_type == "Movie" %}selected{% endif %}>Movie</option>
            <option value="TV Show" {% if selected_type == "TV Show" %}selected{% endif %}>TV Show</option>
        </select>
        <button type="submit">Apply Filter</button>
    </form>

    <div class="chips">
        <span class="chip">
            Showing:
            {% if selected_type == "All" %}
                All content
            {% else %}
                {{ selected_type }}s
            {% endif %}
        </span>
        <span class="chip">Top 10 entries per table</span>
    </div>

    <div class="grid">
        <!-- Top Actors -->
        <section class="card">
            <h2>Top 10 Actors</h2>
            <p class="card-subtitle">
                Actors with the highest number of titles in the filtered catalog.
            </p>
            <table>
                <thead>
                <tr>
                    <th>Actor</th>
                    <th class="numeric">Number of Titles</th>
                </tr>
                </thead>
                <tbody>
                {% for row in top_actors %}
                <tr>
                    <td>{{ row.actor }}</td>
                    <td class="numeric">{{ row.count }}</td>
                </tr>
                {% endfor %}
                {% if top_actors|length == 0 %}
                <tr>
                    <td colspan="2">No actor data available for this filter.</td>
                </tr>
                {% endif %}
                </tbody>
            </table>
        </section>

        <!-- Top Countries -->
        <section class="card">
            <h2>Top 10 Countries</h2>
            <p class="card-subtitle">
                Countries producing the most titles in the filtered catalog.
            </p>
            <table>
                <thead>
                <tr>
                    <th>Country</th>
                    <th class="numeric">Number of Titles</th>
                </tr>
                </thead>
                <tbody>
                {% for row in top_countries %}
                <tr>
                    <td>{{ row.country }}</td>
                    <td class="numeric">{{ row.count }}</td>
                </tr>
                {% endfor %}
                {% if top_countries|length == 0 %}
                <tr>
                    <td colspan="2">No country data available for this filter.</td>
                </tr>
                {% endif %}
                </tbody>
            </table>
        </section>
    </div>

    <footer>
        Data source: netflix_cleaned.csv (Flask demo).
    </footer>
</div>
</body>
</html>
